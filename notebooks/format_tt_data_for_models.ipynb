# %% [markdown]
# As a brief background:
#
# I want to gather scores for a subset of TikTok data to compare the quality of our models - Appen managed services - Our moderator team
#
# On meta, this is an easy task, as there is infrastructure built in our resolvers to do this.
#
# This does not exist for TikTok.
#
# I created a protocol that could possibly facilitate the scoring of arbitrary TikTok content.
#
# The problem?
#
# *There are no nodes that do frame extraction/thumbnails for TikTok videos*
# This is a notebook to bridge that gap.
#
# Input: TikTok content with Metadata/videos downloaded
# Output: TikTok content with frames extracted and "content_type" set to "VIDEO"

# %%
import itertools
from qa_frame.models.avro.schemas.video import Content, Video
from requests import RequestException

from base import BaseScript

# %%
from qa_frame.models.environment import EnvConfig

CONFIG = EnvConfig.get()
RUN_ID = 1675808881

# %%
import snowflake.connector
from qa_frame.interfaces.db.snowflake import SnowflakeDriver


class InferenceCompareReader(SnowflakeDriver):

    def read_content_from_run_id(self, run_id: int | str) -> list[Content]:
        """
        Reads content from the ``QA_FRAME_INFERENCE_COMPARE`` table for a certain run_id
        Parameters
        ----------
        run_id : int | str
            ID of the inference compare run to read content for

        Returns
        -------
        contents : list[Content]
            Content objects read
        """
        return [Content(**row["OUTPUT_DATA"]) for row in self._read(
            """
            SELECT OUTPUT_DATA
            FROM STAGING.QA_FRAME_INFERENCE_COMPARE
            WHERE RUN_ID = '%s'
            """, run_id
        )]

reader = InferenceCompareReader(snowflake.connector.connect(**CONFIG.interface.db.snowflake.__dict__), CONFIG.interface.db.snowflake.environment)

# %%
print([c.content_id for c in reader.read_content_from_run_id(RUN_ID)])
# Out:
# []

# %%
"""
Gathers TikTok video IDs that need to be scored
"""
from qa_frame.interfaces.external.s3 import S3Client
from qa_frame.consts.providers.s3 import SamplePostsCSV


s3 = S3Client(CONFIG.external.s3_client)
tiktok_video_ids = s3.read_csv(
    url=str(SamplePostsCSV.AMS_HPQ_TT_DATA.value),
    filter_=lambda csv_: (
        Video(**{"content_id": row["content_id"][1:-1]})
        for row in csv_
    )
)  # Formatted as video.Video objects

# %%
"""
Gathers metadata for our video IDs

Must port-forward the TikTok metadata service
"""
from qa_frame.interfaces.api.clients.seldon import SeldonClient


class GatherTiktokMetadataForVideos(BaseScript):

    name = "gather_tiktok_metadata"

    def __init__(self):
        super().__init__()
        self.client = SeldonClient[Video, Video](base_url="http://localhost:8080/api/v1.0")

    def run(self):
        batch_size = 50
        scored_content_count = 0

        while batch := list(itertools.islice(tiktok_video_ids, batch_size)):
            predictions, retry = [], True
            while retry:
                try:
                    predictions = [v for v in self.client.predictions(batch) if v.metadata_fetch_status == 200]
                    scored_content_count += len(predictions)
                    retry = False
                except RequestException:
                    continue

            self._write_json_files("tiktok_videos_with_metadata", *predictions)
            self.logger.info("Predictions received", total_count=scored_content_count)

GatherTiktokMetadataForVideos().run()
# Out:
# {
#   "asctime": "2023-02-07 16:15:05",
#   "levelname": "INFO",
#   "lineno": 54,
#   "msg": "Initialized output directory",
#   "output_path": "/Users/ryan.demarigny/PycharmProjects/qa-frame-notebooks/notebooks/output/gather_tiktok_metadata"
# }
#
# {
#   "asctime": "2023-02-07 16:15:07",
#   "levelname": "INFO",
#   "lineno": 114,
#   "msg": "Writing file",
#   "file_name": "tiktok_videos_with_metadata_0.json"
# }
#
# {
#   "asctime": "2023-02-07 16:15:07",
#   "levelname": "INFO",
#   "lineno": 32,
#   "msg": "Predictions received",
#   "total_count": 34
# }
#
# {
#   "asctime": "2023-02-07 16:15:08",
#   "levelname": "INFO",
#   "lineno": 32,
#   "msg": "Predictions received",
#   "total_count": 66
# }
#
# {
#   "asctime": "2023-02-07 16:15:10",
#   "levelname": "INFO",
#   "lineno": 32,
#   "msg": "Predictions received",
#   "total_count": 108
# }
#
# {
#   "asctime": "2023-02-07 16:15:11",
#   "levelname": "INFO",
#   "lineno": 32,
#   "msg": "Predictions received",
#   "total_count": 150
# }
#
# {
#   "asctime": "2023-02-07 16:15:13",
#   "levelname": "INFO",
#   "lineno": 32,
#   "msg": "Predictions received",
#   "total_count": 189
# }
#
# {
#   "asctime": "2023-02-07 16:15:14",
#   "levelname": "INFO",
#   "lineno": 114,
#   "msg": "Writing file",
#   "file_name": "tiktok_videos_with_metadata_1.json"
# }
#
# {
#   "asctime": "2023-02-07 16:15:14",
#   "levelname": "INFO",
#   "lineno": 32,
#   "msg": "Predictions received",
#   "total_count": 231
# }
#
# {
#   "asctime": "2023-02-07 16:15:16",
#   "levelname": "INFO",
#   "lineno": 32,
#   "msg": "Predictions received",
#   "total_count": 272
# }
#
# {
#   "asctime": "2023-02-07 16:15:17",
#   "levelname": "INFO",
#   "lineno": 32,
#   "msg": "Predictions received",
#   "total_count": 302
# }
#
# {
#   "asctime": "2023-02-07 16:15:18",
#   "levelname": "INFO",
#   "lineno": 32,
#   "msg": "Predictions received",
#   "total_count": 342
# }
#
# {
#   "asctime": "2023-02-07 16:15:20",
#   "levelname": "INFO",
#   "lineno": 32,
#   "msg": "Predictions received",
#   "total_count": 384
# }
#
# {
#   "asctime": "2023-02-07 16:15:21",
#   "levelname": "INFO",
#   "lineno": 114,
#   "msg": "Writing file",
#   "file_name": "tiktok_videos_with_metadata_2.json"
# }
#
# {
#   "asctime": "2023-02-07 16:15:21",
#   "levelname": "INFO",
#   "lineno": 32,
#   "msg": "Predictions received",
#   "total_count": 422
# }
#
# {
#   "asctime": "2023-02-07 16:15:23",
#   "levelname": "INFO",
#   "lineno": 32,
#   "msg": "Predictions received",
#   "total_count": 466
# }
#
# {
#   "asctime": "2023-02-07 16:15:24",
#   "levelname": "INFO",
#   "lineno": 32,
#   "msg": "Predictions received",
#   "total_count": 501
# }
#
# {
#   "asctime": "2023-02-07 16:15:26",
#   "levelname": "INFO",
#   "lineno": 32,
#   "msg": "Predictions received",
#   "total_count": 536
# }
#
# {
#   "asctime": "2023-02-07 16:15:27",
#   "levelname": "INFO",
#   "lineno": 32,
#   "msg": "Predictions received",
#   "total_count": 576
# }
#
# {
#   "asctime": "2023-02-07 16:15:28",
#   "levelname": "INFO",
#   "lineno": 114,
#   "msg": "Writing file",
#   "file_name": "tiktok_videos_with_metadata_3.json"
# }
#
# {
#   "asctime": "2023-02-07 16:15:28",
#   "levelname": "INFO",
#   "lineno": 32,
#   "msg": "Predictions received",
#   "total_count": 616
# }
#
# {
#   "asctime": "2023-02-07 16:15:30",
#   "levelname": "INFO",
#   "lineno": 32,
#   "msg": "Predictions received",
#   "total_count": 654
# }
#
# {
#   "asctime": "2023-02-07 16:15:31",
#   "levelname": "INFO",
#   "lineno": 32,
#   "msg": "Predictions received",
#   "total_count": 691
# }
#
# {
#   "asctime": "2023-02-07 16:15:33",
#   "levelname": "INFO",
#   "lineno": 32,
#   "msg": "Predictions received",
#   "total_count": 724
# }
#
# {
#   "asctime": "2023-02-07 16:15:34",
#   "levelname": "INFO",
#   "lineno": 32,
#   "msg": "Predictions received",
#   "total_count": 761
# }
#
# {
#   "asctime": "2023-02-07 16:15:35",
#   "levelname": "INFO",
#   "lineno": 32,
#   "msg": "Predictions received",
#   "total_count": 801
# }
#
# {
#   "asctime": "2023-02-07 16:15:37",
#   "levelname": "INFO",
#   "lineno": 114,
#   "msg": "Writing file",
#   "file_name": "tiktok_videos_with_metadata_4.json"
# }
#
# {
#   "asctime": "2023-02-07 16:15:37",
#   "levelname": "INFO",
#   "lineno": 32,
#   "msg": "Predictions received",
#   "total_count": 842
# }
#
# {
#   "asctime": "2023-02-07 16:15:38",
#   "levelname": "INFO",
#   "lineno": 32,
#   "msg": "Predictions received",
#   "total_count": 884
# }
#
# {
#   "asctime": "2023-02-07 16:15:40",
#   "levelname": "INFO",
#   "lineno": 32,
#   "msg": "Predictions received",
#   "total_count": 924
# }
#
# {
#   "asctime": "2023-02-07 16:15:41",
#   "levelname": "INFO",
#   "lineno": 32,
#   "msg": "Predictions received",
#   "total_count": 965
# }
#
# {
#   "asctime": "2023-02-07 16:15:42",
#   "levelname": "INFO",
#   "lineno": 114,
#   "msg": "Writing file",
#   "file_name": "tiktok_videos_with_metadata_5.json"
# }
#
# {
#   "asctime": "2023-02-07 16:15:42",
#   "levelname": "INFO",
#   "lineno": 32,
#   "msg": "Predictions received",
#   "total_count": 1006
# }
#
# {
#   "asctime": "2023-02-07 16:15:44",
#   "levelname": "INFO",
#   "lineno": 32,
#   "msg": "Predictions received",
#   "total_count": 1041
# }
#
# {
#   "asctime": "2023-02-07 16:15:45",
#   "levelname": "INFO",
#   "lineno": 32,
#   "msg": "Predictions received",
#   "total_count": 1081
# }
#
# {
#   "asctime": "2023-02-07 16:15:47",
#   "levelname": "INFO",
#   "lineno": 32,
#   "msg": "Predictions received",
#   "total_count": 1120
# }
#
# {
#   "asctime": "2023-02-07 16:15:48",
#   "levelname": "INFO",
#   "lineno": 32,
#   "msg": "Predictions received",
#   "total_count": 1159
# }
#
# {
#   "asctime": "2023-02-07 16:15:49",
#   "levelname": "INFO",
#   "lineno": 114,
#   "msg": "Writing file",
#   "file_name": "tiktok_videos_with_metadata_6.json"
# }
#
# {
#   "asctime": "2023-02-07 16:15:49",
#   "levelname": "INFO",
#   "lineno": 32,
#   "msg": "Predictions received",
#   "total_count": 1203
# }
#
# {
#   "asctime": "2023-02-07 16:15:51",
#   "levelname": "INFO",
#   "lineno": 32,
#   "msg": "Predictions received",
#   "total_count": 1241
# }
#
# {
#   "asctime": "2023-02-07 16:15:52",
#   "levelname": "INFO",
#   "lineno": 32,
#   "msg": "Predictions received",
#   "total_count": 1281
# }
#
# {
#   "asctime": "2023-02-07 16:15:53",
#   "levelname": "INFO",
#   "lineno": 32,
#   "msg": "Predictions received",
#   "total_count": 1317
# }
#
# {
#   "asctime": "2023-02-07 16:15:55",
#   "levelname": "INFO",
#   "lineno": 32,
#   "msg": "Predictions received",
#   "total_count": 1317
# }
#
# {
#   "asctime": "2023-02-07 16:15:56",
#   "levelname": "INFO",
#   "lineno": 32,
#   "msg": "Predictions received",
#   "total_count": 1356
# }
#
# {
#   "asctime": "2023-02-07 16:15:57",
#   "levelname": "INFO",
#   "lineno": 32,
#   "msg": "Predictions received",
#   "total_count": 1356
# }
#
# {
#   "asctime": "2023-02-07 16:15:58",
#   "levelname": "INFO",
#   "lineno": 32,
#   "msg": "Predictions received",
#   "total_count": 1386
# }
#
# {
#   "asctime": "2023-02-07 16:16:00",
#   "levelname": "INFO",
#   "lineno": 114,
#   "msg": "Writing file",
#   "file_name": "tiktok_videos_with_metadata_7.json"
# }
#
# {
#   "asctime": "2023-02-07 16:16:00",
#   "levelname": "INFO",
#   "lineno": 32,
#   "msg": "Predictions received",
#   "total_count": 1424
# }
#
# {
#   "asctime": "2023-02-07 16:16:01",
#   "levelname": "INFO",
#   "lineno": 32,
#   "msg": "Predictions received",
#   "total_count": 1469
# }
#
# {
#   "asctime": "2023-02-07 16:16:03",
#   "levelname": "INFO",
#   "lineno": 32,
#   "msg": "Predictions received",
#   "total_count": 1506
# }
#
# {
#   "asctime": "2023-02-07 16:16:04",
#   "levelname": "INFO",
#   "lineno": 32,
#   "msg": "Predictions received",
#   "total_count": 1545
# }
#
# {
#   "asctime": "2023-02-07 16:16:09",
#   "levelname": "INFO",
#   "lineno": 32,
#   "msg": "Predictions received",
#   "total_count": 1589
# }
#
# {
#   "asctime": "2023-02-07 16:16:10",
#   "levelname": "INFO",
#   "lineno": 114,
#   "msg": "Writing file",
#   "file_name": "tiktok_videos_with_metadata_8.json"
# }
#
# {
#   "asctime": "2023-02-07 16:16:10",
#   "levelname": "INFO",
#   "lineno": 32,
#   "msg": "Predictions received",
#   "total_count": 1627
# }
#
# {
#   "asctime": "2023-02-07 16:16:12",
#   "levelname": "INFO",
#   "lineno": 32,
#   "msg": "Predictions received",
#   "total_count": 1668
# }
#
# {
#   "asctime": "2023-02-07 16:16:14",
#   "levelname": "INFO",
#   "lineno": 32,
#   "msg": "Predictions received",
#   "total_count": 1702
# }
#
# {
#   "asctime": "2023-02-07 16:16:15",
#   "levelname": "INFO",
#   "lineno": 32,
#   "msg": "Predictions received",
#   "total_count": 1732
# }
#
# {
#   "asctime": "2023-02-07 16:16:17",
#   "levelname": "INFO",
#   "lineno": 32,
#   "msg": "Predictions received",
#   "total_count": 1776
# }
#
# {
#   "asctime": "2023-02-07 16:16:18",
#   "levelname": "INFO",
#   "lineno": 114,
#   "msg": "Writing file",
#   "file_name": "tiktok_videos_with_metadata_9.json"
# }
#
# {
#   "asctime": "2023-02-07 16:16:18",
#   "levelname": "INFO",
#   "lineno": 32,
#   "msg": "Predictions received",
#   "total_count": 1817
# }
#
# {
#   "asctime": "2023-02-07 16:16:19",
#   "levelname": "INFO",
#   "lineno": 32,
#   "msg": "Predictions received",
#   "total_count": 1854
# }
#
# {
#   "asctime": "2023-02-07 16:16:21",
#   "levelname": "INFO",
#   "lineno": 32,
#   "msg": "Predictions received",
#   "total_count": 1895
# }
#
# {
#   "asctime": "2023-02-07 16:16:22",
#   "levelname": "INFO",
#   "lineno": 32,
#   "msg": "Predictions received",
#   "total_count": 1937
# }
#
# {
#   "asctime": "2023-02-07 16:16:24",
#   "levelname": "INFO",
#   "lineno": 32,
#   "msg": "Predictions received",
#   "total_count": 1979
# }
#
# {
#   "asctime": "2023-02-07 16:16:25",
#   "levelname": "INFO",
#   "lineno": 114,
#   "msg": "Writing file",
#   "file_name": "tiktok_videos_with_metadata_10.json"
# }
#
# {
#   "asctime": "2023-02-07 16:16:25",
#   "levelname": "INFO",
#   "lineno": 32,
#   "msg": "Predictions received",
#   "total_count": 2022
# }
#
# {
#   "asctime": "2023-02-07 16:16:27",
#   "levelname": "INFO",
#   "lineno": 32,
#   "msg": "Predictions received",
#   "total_count": 2059
# }
#
# {
#   "asctime": "2023-02-07 16:16:28",
#   "levelname": "INFO",
#   "lineno": 32,
#   "msg": "Predictions received",
#   "total_count": 2096
# }
#
# {
#   "asctime": "2023-02-07 16:16:29",
#   "levelname": "INFO",
#   "lineno": 32,
#   "msg": "Predictions received",
#   "total_count": 2134
# }
#
# {
#   "asctime": "2023-02-07 16:16:30",
#   "levelname": "INFO",
#   "lineno": 32,
#   "msg": "Predictions received",
#   "total_count": 2175
# }
#
# {
#   "asctime": "2023-02-07 16:16:32",
#   "levelname": "INFO",
#   "lineno": 114,
#   "msg": "Writing file",
#   "file_name": "tiktok_videos_with_metadata_11.json"
# }
#
# {
#   "asctime": "2023-02-07 16:16:32",
#   "levelname": "INFO",
#   "lineno": 32,
#   "msg": "Predictions received",
#   "total_count": 2216
# }
#
# {
#   "asctime": "2023-02-07 16:16:33",
#   "levelname": "INFO",
#   "lineno": 32,
#   "msg": "Predictions received",
#   "total_count": 2251
# }
#
# {
#   "asctime": "2023-02-07 16:16:35",
#   "levelname": "INFO",
#   "lineno": 32,
#   "msg": "Predictions received",
#   "total_count": 2289
# }
#
# {
#   "asctime": "2023-02-07 16:16:36",
#   "levelname": "INFO",
#   "lineno": 32,
#   "msg": "Predictions received",
#   "total_count": 2328
# }
#
# {
#   "asctime": "2023-02-07 16:16:37",
#   "levelname": "INFO",
#   "lineno": 32,
#   "msg": "Predictions received",
#   "total_count": 2368
# }
#
# {
#   "asctime": "2023-02-07 16:16:39",
#   "levelname": "INFO",
#   "lineno": 114,
#   "msg": "Writing file",
#   "file_name": "tiktok_videos_with_metadata_12.json"
# }
#
# {
#   "asctime": "2023-02-07 16:16:39",
#   "levelname": "INFO",
#   "lineno": 32,
#   "msg": "Predictions received",
#   "total_count": 2409
# }
#
# {
#   "asctime": "2023-02-07 16:16:40",
#   "levelname": "INFO",
#   "lineno": 32,
#   "msg": "Predictions received",
#   "total_count": 2449
# }
#
# {
#   "asctime": "2023-02-07 16:16:41",
#   "levelname": "INFO",
#   "lineno": 32,
#   "msg": "Predictions received",
#   "total_count": 2487
# }
#
# {
#   "asctime": "2023-02-07 16:16:42",
#   "levelname": "INFO",
#   "lineno": 32,
#   "msg": "Predictions received",
#   "total_count": 2525
# }
#
# {
#   "asctime": "2023-02-07 16:16:44",
#   "levelname": "INFO",
#   "lineno": 32,
#   "msg": "Predictions received",
#   "total_count": 2564
# }
#
# {
#   "asctime": "2023-02-07 16:16:46",
#   "levelname": "INFO",
#   "lineno": 114,
#   "msg": "Writing file",
#   "file_name": "tiktok_videos_with_metadata_13.json"
# }
#
# {
#   "asctime": "2023-02-07 16:16:46",
#   "levelname": "INFO",
#   "lineno": 32,
#   "msg": "Predictions received",
#   "total_count": 2608
# }
#
# {
#   "asctime": "2023-02-07 16:16:48",
#   "levelname": "INFO",
#   "lineno": 32,
#   "msg": "Predictions received",
#   "total_count": 2649
# }
#
# {
#   "asctime": "2023-02-07 16:16:49",
#   "levelname": "INFO",
#   "lineno": 32,
#   "msg": "Predictions received",
#   "total_count": 2686
# }
#
# {
#   "asctime": "2023-02-07 16:16:51",
#   "levelname": "INFO",
#   "lineno": 32,
#   "msg": "Predictions received",
#   "total_count": 2727
# }
#
# {
#   "asctime": "2023-02-07 16:16:52",
#   "levelname": "INFO",
#   "lineno": 32,
#   "msg": "Predictions received",
#   "total_count": 2771
# }
#
# {
#   "asctime": "2023-02-07 16:16:54",
#   "levelname": "INFO",
#   "lineno": 114,
#   "msg": "Writing file",
#   "file_name": "tiktok_videos_with_metadata_14.json"
# }
#
# {
#   "asctime": "2023-02-07 16:16:54",
#   "levelname": "INFO",
#   "lineno": 32,
#   "msg": "Predictions received",
#   "total_count": 2817
# }
#
# {
#   "asctime": "2023-02-07 16:16:55",
#   "levelname": "INFO",
#   "lineno": 32,
#   "msg": "Predictions received",
#   "total_count": 2859
# }
#
# {
#   "asctime": "2023-02-07 16:16:57",
#   "levelname": "INFO",
#   "lineno": 32,
#   "msg": "Predictions received",
#   "total_count": 2898
# }
#
# {
#   "asctime": "2023-02-07 16:16:58",
#   "levelname": "INFO",
#   "lineno": 32,
#   "msg": "Predictions received",
#   "total_count": 2936
# }
#
# {
#   "asctime": "2023-02-07 16:16:59",
#   "levelname": "INFO",
#   "lineno": 32,
#   "msg": "Predictions received",
#   "total_count": 2979
# }
#
# {
#   "asctime": "2023-02-07 16:17:01",
#   "levelname": "INFO",
#   "lineno": 114,
#   "msg": "Writing file",
#   "file_name": "tiktok_videos_with_metadata_15.json"
# }
#
# {
#   "asctime": "2023-02-07 16:17:01",
#   "levelname": "INFO",
#   "lineno": 32,
#   "msg": "Predictions received",
#   "total_count": 3017
# }
#
# {
#   "asctime": "2023-02-07 16:17:02",
#   "levelname": "INFO",
#   "lineno": 32,
#   "msg": "Predictions received",
#   "total_count": 3054
# }
#
# {
#   "asctime": "2023-02-07 16:17:04",
#   "levelname": "INFO",
#   "lineno": 32,
#   "msg": "Predictions received",
#   "total_count": 3096
# }
#
# {
#   "asctime": "2023-02-07 16:17:05",
#   "levelname": "INFO",
#   "lineno": 32,
#   "msg": "Predictions received",
#   "total_count": 3137
# }
#
# {
#   "asctime": "2023-02-07 16:17:07",
#   "levelname": "INFO",
#   "lineno": 32,
#   "msg": "Predictions received",
#   "total_count": 3178
# }
#
# {
#   "asctime": "2023-02-07 16:17:08",
#   "levelname": "INFO",
#   "lineno": 114,
#   "msg": "Writing file",
#   "file_name": "tiktok_videos_with_metadata_16.json"
# }
#
# {
#   "asctime": "2023-02-07 16:17:08",
#   "levelname": "INFO",
#   "lineno": 32,
#   "msg": "Predictions received",
#   "total_count": 3215
# }
#
# {
#   "asctime": "2023-02-07 16:17:09",
#   "levelname": "INFO",
#   "lineno": 32,
#   "msg": "Predictions received",
#   "total_count": 3239
# }
