# %% [markdown]
# As a brief background:
#
# I want to gather scores for a subset of TikTok data to compare the quality of our models - Appen managed services - Our moderator team
#
# On meta, this is an easy task, as there is infrastructure built in our resolvers to do this.
#
# This does not exist for TikTok.
#
# I created a protocol that could possibly facilitate the scoring of arbitrary TikTok content.
#
# The problem?
#
# *There are no nodes that do frame extraction/thumbnails for TikTok videos*
# This is a notebook to bridge that gap.
#
# Input: TikTok content with Metadata/videos downloaded
# Output: TikTok content with frames extracted and "content_type" set to "VIDEO"

# %%
import itertools
from qa_frame.models.avro.schemas.video import Content, Video, ContentType, Derived
from qa_frame.interfaces.api.clients.frs import FRSClient
from qa_frame.consts.api import frs
from qa_frame.interfaces.api.clients.seldon import SeldonClient
from qa_frame.interfaces.external.s3 import S3Client
from qa_frame.consts.providers.s3 import SamplePostsCSV
from requests import RequestException
import snowflake.connector
from qa_frame.interfaces.db.snowflake import SnowflakeDriver
from qa_frame.models.environment import EnvConfig

from base import BaseScript

CONFIG = EnvConfig.get()
RUN_ID = 1675808881

# %%
class InferenceCompareReader(SnowflakeDriver):

    def read_content_from_run_id(self, run_id: int | str) -> list[Content]:
        """
        Reads content from the ``QA_FRAME_INFERENCE_COMPARE`` table for a certain run_id
        Parameters
        ----------
        run_id : int | str
            ID of the inference compare run to read content for

        Returns
        -------
        contents : list[Content]
            Content objects read
        """
        return [Content(**row["OUTPUT_DATA"]) for row in self._read(
            """
            SELECT OUTPUT_DATA
            FROM STAGING.QA_FRAME_INFERENCE_COMPARE
            WHERE RUN_ID = '%s'
            """, run_id
        )]

reader = InferenceCompareReader(snowflake.connector.connect(**CONFIG.interface.db.snowflake.__dict__), CONFIG.interface.db.snowflake.environment)

# %%
print([c.content_id for c in reader.read_content_from_run_id(RUN_ID)])

# %%
"""
Gathers TikTok video IDs that need to be scored
"""
s3 = S3Client(CONFIG.external.s3_client)
tiktok_video_ids = s3.read_csv(
    url=str(SamplePostsCSV.AMS_HPQ_TT_DATA.value),
    filter_=lambda csv_: (
        Video(**{"content_id": row["content_id"][1:-1]})
        for row in csv_
    )
)  # Formatted as video.Video objects

# %%
"""
Gathers metadata for our video IDs

Must port-forward the TikTok metadata service
"""

class GatherTiktokMetadataForVideos(BaseScript):

    name = "gather_tiktok_metadata"

    def __init__(self):
        super().__init__()
        self.client = SeldonClient[Video, Video](base_url="http://localhost:8080/api/v1.0")

    def run(self):
        batch_size = 50
        scored_content_count = 0

        while batch := list(itertools.islice(tiktok_video_ids, batch_size)):
            predictions, retry = [], True
            while retry:
                try:
                    predictions = [v for v in self.client.predictions(batch) if v.metadata_fetch_status == 200]
                    scored_content_count += len(predictions)
                    retry = False
                except RequestException:
                    continue

            self._write_json_files("tiktok_videos_with_metadata", *predictions)
            self.logger.info("Predictions received", total_count=scored_content_count)

GatherTiktokMetadataForVideos().run()

# %%
"""
DownloadTikTokVideos
"""

class DownloadTikTokVideos(BaseScript):
    name = "download_tiktok_videos"

    def __init__(self):
        super().__init__()
        self.client = SeldonClient[Video, Video](base_url="http://localhost:8080/api/v1.0")

    def run(self):
        batch_size = 50
        scored_content_count = 0

        videos_with_metadata = self._read_json_files("tiktok_videos_with_metadata_1675844107", Video)
        while batch := list(itertools.islice(videos_with_metadata, batch_size)):
            predictions, retry = [], True
            while retry:
                try:
                    predictions = self.client.predictions(batch)
                    scored_content_count += len(predictions)
                    retry = False
                except RequestException:
                    continue

            self._write_json_files("tiktok_videos_downloaded", *predictions)
            self.logger.info("Predictions received", total_count=scored_content_count)

DownloadTikTokVideos().run()

# %%
"""
Merge together metadata and download url
"""

class MergeTiktokMetadataAndDownloadedVideo(BaseScript):  # Also will add a content_type
    name = "merge_tiktok_videos"

    def run(self):
        for video_metadata in self._read_json_files("tiktok_videos_with_metadata_1675844107", Content):
            corresponding_downloaded_video = next(
                v
                for v in self._read_json_files("tiktok_videos_downloaded_1675910561", Video)
                if v.content_id == video_metadata.content_id
            )
            merged_video = Content(**video_metadata.as_dict() | {"content_type": ContentType.VIDEO, "video_url": corresponding_downloaded_video.video_url})
            self._write_json_files("videos", merged_video)

MergeTiktokMetadataAndDownloadedVideo().run()

# %%
"""
Extract frames from merged videos
"""
from threading import Thread
from concurrent.futures import ThreadPoolExecutor, wait
from queue import Queue
from requests import ConnectionError, Session
from requests.adapters import HTTPAdapter
from time import sleep


max_video_seconds = 60
num_threads = 32


class ExtractTiktokVideoFrames(BaseScript):
    name = "extract_tiktok_video_frames"

    def __init__(self):
        super().__init__()
        self.session = Session()
        self.session.mount("http://", HTTPAdapter(pool_connections=num_threads, pool_maxsize=num_threads))
        self.frs = FRSClient("http://localhost:8080", session=self.session)
        self.contents = self._read_json_files("videos_1675913568", Content)
        self.contents_to_write = Queue[Content]()

    def write_to_file(self):
        while True:
            if not self.contents_to_write.empty():
                self._write_json_files("videos_with_frames", self.contents_to_write.get())

    def get_frames(self, content: Content):
        retry = True
        retry_count = 0

        while retry:
            try:
                response = self.frs.store_video_frames(
                    video_uri=content.video_url,
                    platform=frs.Platform.TIKTOK,
                    content_id=content.content_id,
                    max_seconds=max_video_seconds
                )
                retry = False
                self.contents_to_write.put(Content(**content.as_dict() | {"derived": Derived(**response["derived"]), "thumbnail": None}))
            except ConnectionError:
                print("connection error, retrying in 10")
                sleep(10)
            except RequestException:
                if retry_count == 2:
                    return
                retry_count += 1
                print("request exception, waiting 10 and retrying")
                sleep(10)

    def run(self):
        content_writer = Thread(target=self.write_to_file)
        content_writer.daemon = True
        content_writer.start()

        with ThreadPoolExecutor(max_workers=num_threads) as thread_pool:
            futures = thread_pool.map(self.get_frames, self._read_json_files("videos_1675913568", Content))
            wait(futures)
        content_writer.join()

ExtractTiktokVideoFrames().run()

# %%
class RunTikTokVideosThroughModel(BaseScript):
    name = "scored_tiktok_videos"
    model_name = "seldon-meta-combiner-predictor"

    def __init__(self):
        super().__init__()
        self.client = SeldonClient[Content, Content](
            base_url="http://localhost:8080/api/v1.0",
            serializer=lambda obj: obj.as_dict() | {"thumbnail": None}
        )

    def run(self):
        batch_size = 50
        scored_content_count = 0

        videos = self._read_json_files("seldon-onnx-combined_1676003196", Content)
        while batch := list(itertools.islice(videos, batch_size)):
            predictions, retry = [], True
            while retry:
                try:
                    predictions = self.client.predictions(batch)
                    scored_content_count += len(predictions)
                    self.logger.info("Predictions received", total_count=scored_content_count)
                    retry = False
                except RequestException:
                    continue

            for video, prediction in zip(batch, predictions):  # order is preserved
                dict_video = video.as_dict()
                if "derived" not in dict_video:
                    dict_video["derived"] = {}

                dict_video["derived"]["taxonomy_scores"] = prediction.derived.taxonomy_scores
                self._write_json_files(self.model_name, Content(**dict_video))

RunTikTokVideosThroughModel().run()
# Out:
# {
#   "asctime": "2023-02-09 14:11:25",
#   "levelname": "INFO",
#   "lineno": 54,
#   "msg": "Initialized output directory",
#   "output_path": "/Users/ryan.demarigny/PycharmProjects/qa-frame-notebooks/notebooks/output/scored_tiktok_videos"
# }
#
# {
#   "asctime": "2023-02-09 14:11:25",
#   "levelname": "INFO",
#   "lineno": 152,
#   "msg": "Reading file",
#   "file_path": "/Users/ryan.demarigny/PycharmProjects/qa-frame-notebooks/notebooks/input/seldon-onnx-combined_1676003196/seldon-onnx-combined_7.json"
# }
#
# {
#   "asctime": "2023-02-09 14:11:29",
#   "levelname": "INFO",
#   "lineno": 23,
#   "msg": "Predictions received",
#   "total_count": 50
# }
#
# {
#   "asctime": "2023-02-09 14:11:29",
#   "levelname": "INFO",
#   "lineno": 114,
#   "msg": "Writing file",
#   "file_name": "seldon-meta-combiner-predictor_0.json"
# }
#
# {
#   "asctime": "2023-02-09 14:11:34",
#   "levelname": "INFO",
#   "lineno": 23,
#   "msg": "Predictions received",
#   "total_count": 100
# }
#
# {
#   "asctime": "2023-02-09 14:11:38",
#   "levelname": "INFO",
#   "lineno": 23,
#   "msg": "Predictions received",
#   "total_count": 150
# }
#
# {
#   "asctime": "2023-02-09 14:11:42",
#   "levelname": "INFO",
#   "lineno": 23,
#   "msg": "Predictions received",
#   "total_count": 200
# }
#
# {
#   "asctime": "2023-02-09 14:11:42",
#   "levelname": "INFO",
#   "lineno": 152,
#   "msg": "Reading file",
#   "file_path": "/Users/ryan.demarigny/PycharmProjects/qa-frame-notebooks/notebooks/input/seldon-onnx-combined_1676003196/seldon-onnx-combined_10.json"
# }
#
# {
#   "asctime": "2023-02-09 14:11:46",
#   "levelname": "INFO",
#   "lineno": 23,
#   "msg": "Predictions received",
#   "total_count": 250
# }
#
# {
#   "asctime": "2023-02-09 14:11:46",
#   "levelname": "INFO",
#   "lineno": 114,
#   "msg": "Writing file",
#   "file_name": "seldon-meta-combiner-predictor_1.json"
# }
#
# {
#   "asctime": "2023-02-09 14:11:50",
#   "levelname": "INFO",
#   "lineno": 23,
#   "msg": "Predictions received",
#   "total_count": 300
# }
#
# {
#   "asctime": "2023-02-09 14:11:54",
#   "levelname": "INFO",
#   "lineno": 23,
#   "msg": "Predictions received",
#   "total_count": 350
# }
#
# {
#   "asctime": "2023-02-09 14:11:58",
#   "levelname": "INFO",
#   "lineno": 23,
#   "msg": "Predictions received",
#   "total_count": 400
# }
#
# {
#   "asctime": "2023-02-09 14:11:59",
#   "levelname": "INFO",
#   "lineno": 152,
#   "msg": "Reading file",
#   "file_path": "/Users/ryan.demarigny/PycharmProjects/qa-frame-notebooks/notebooks/input/seldon-onnx-combined_1676003196/seldon-onnx-combined_11.json"
# }
#
# {
#   "asctime": "2023-02-09 14:12:02",
#   "levelname": "INFO",
#   "lineno": 23,
#   "msg": "Predictions received",
#   "total_count": 450
# }
#
# {
#   "asctime": "2023-02-09 14:12:02",
#   "levelname": "INFO",
#   "lineno": 114,
#   "msg": "Writing file",
#   "file_name": "seldon-meta-combiner-predictor_2.json"
# }
#
# {
#   "asctime": "2023-02-09 14:12:06",
#   "levelname": "INFO",
#   "lineno": 23,
#   "msg": "Predictions received",
#   "total_count": 500
# }
#
# {
#   "asctime": "2023-02-09 14:12:10",
#   "levelname": "INFO",
#   "lineno": 23,
#   "msg": "Predictions received",
#   "total_count": 550
# }
#
# {
#   "asctime": "2023-02-09 14:12:14",
#   "levelname": "INFO",
#   "lineno": 23,
#   "msg": "Predictions received",
#   "total_count": 600
# }
#
# {
#   "asctime": "2023-02-09 14:12:14",
#   "levelname": "INFO",
#   "lineno": 152,
#   "msg": "Reading file",
#   "file_path": "/Users/ryan.demarigny/PycharmProjects/qa-frame-notebooks/notebooks/input/seldon-onnx-combined_1676003196/seldon-onnx-combined_6.json"
# }
#
# {
#   "asctime": "2023-02-09 14:12:17",
#   "levelname": "INFO",
#   "lineno": 23,
#   "msg": "Predictions received",
#   "total_count": 650
# }
#
# {
#   "asctime": "2023-02-09 14:12:17",
#   "levelname": "INFO",
#   "lineno": 114,
#   "msg": "Writing file",
#   "file_name": "seldon-meta-combiner-predictor_3.json"
# }
#
# {
#   "asctime": "2023-02-09 14:12:22",
#   "levelname": "INFO",
#   "lineno": 23,
#   "msg": "Predictions received",
#   "total_count": 700
# }
#
# {
#   "asctime": "2023-02-09 14:12:25",
#   "levelname": "INFO",
#   "lineno": 23,
#   "msg": "Predictions received",
#   "total_count": 750
# }
#
# {
#   "asctime": "2023-02-09 14:12:30",
#   "levelname": "INFO",
#   "lineno": 23,
#   "msg": "Predictions received",
#   "total_count": 800
# }
#
# {
#   "asctime": "2023-02-09 14:12:30",
#   "levelname": "INFO",
#   "lineno": 152,
#   "msg": "Reading file",
#   "file_path": "/Users/ryan.demarigny/PycharmProjects/qa-frame-notebooks/notebooks/input/seldon-onnx-combined_1676003196/seldon-onnx-combined_1.json"
# }
#
# {
#   "asctime": "2023-02-09 14:12:34",
#   "levelname": "INFO",
#   "lineno": 23,
#   "msg": "Predictions received",
#   "total_count": 850
# }
#
# {
#   "asctime": "2023-02-09 14:12:34",
#   "levelname": "INFO",
#   "lineno": 114,
#   "msg": "Writing file",
#   "file_name": "seldon-meta-combiner-predictor_4.json"
# }
#
# {
#   "asctime": "2023-02-09 14:12:38",
#   "levelname": "INFO",
#   "lineno": 23,
#   "msg": "Predictions received",
#   "total_count": 900
# }
#
# {
#   "asctime": "2023-02-09 14:12:42",
#   "levelname": "INFO",
#   "lineno": 23,
#   "msg": "Predictions received",
#   "total_count": 950
# }
#
# {
#   "asctime": "2023-02-09 14:12:46",
#   "levelname": "INFO",
#   "lineno": 23,
#   "msg": "Predictions received",
#   "total_count": 1000
# }
#
# {
#   "asctime": "2023-02-09 14:12:47",
#   "levelname": "INFO",
#   "lineno": 152,
#   "msg": "Reading file",
#   "file_path": "/Users/ryan.demarigny/PycharmProjects/qa-frame-notebooks/notebooks/input/seldon-onnx-combined_1676003196/seldon-onnx-combined_16.json"
# }
#
# {
#   "asctime": "2023-02-09 14:12:47",
#   "levelname": "INFO",
#   "lineno": 152,
#   "msg": "Reading file",
#   "file_path": "/Users/ryan.demarigny/PycharmProjects/qa-frame-notebooks/notebooks/input/seldon-onnx-combined_1676003196/seldon-onnx-combined_0.json"
# }
#
# {
#   "asctime": "2023-02-09 14:12:51",
#   "levelname": "INFO",
#   "lineno": 23,
#   "msg": "Predictions received",
#   "total_count": 1050
# }
#
# {
#   "asctime": "2023-02-09 14:12:51",
#   "levelname": "INFO",
#   "lineno": 114,
#   "msg": "Writing file",
#   "file_name": "seldon-meta-combiner-predictor_5.json"
# }
#
# {
#   "asctime": "2023-02-09 14:12:55",
#   "levelname": "INFO",
#   "lineno": 23,
#   "msg": "Predictions received",
#   "total_count": 1100
# }
#
# {
#   "asctime": "2023-02-09 14:12:59",
#   "levelname": "INFO",
#   "lineno": 23,
#   "msg": "Predictions received",
#   "total_count": 1150
# }
#
# {
#   "asctime": "2023-02-09 14:13:03",
#   "levelname": "INFO",
#   "lineno": 23,
#   "msg": "Predictions received",
#   "total_count": 1200
# }
#
# {
#   "asctime": "2023-02-09 14:13:03",
#   "levelname": "INFO",
#   "lineno": 152,
#   "msg": "Reading file",
#   "file_path": "/Users/ryan.demarigny/PycharmProjects/qa-frame-notebooks/notebooks/input/seldon-onnx-combined_1676003196/seldon-onnx-combined_14.json"
# }
#
# {
#   "asctime": "2023-02-09 14:13:07",
#   "levelname": "INFO",
#   "lineno": 23,
#   "msg": "Predictions received",
#   "total_count": 1250
# }
#
# {
#   "asctime": "2023-02-09 14:13:07",
#   "levelname": "INFO",
#   "lineno": 114,
#   "msg": "Writing file",
#   "file_name": "seldon-meta-combiner-predictor_6.json"
# }
#
# {
#   "asctime": "2023-02-09 14:13:12",
#   "levelname": "INFO",
#   "lineno": 23,
#   "msg": "Predictions received",
#   "total_count": 1300
# }
#
# {
#   "asctime": "2023-02-09 14:13:16",
#   "levelname": "INFO",
#   "lineno": 23,
#   "msg": "Predictions received",
#   "total_count": 1350
# }
#
# {
#   "asctime": "2023-02-09 14:13:20",
#   "levelname": "INFO",
#   "lineno": 23,
#   "msg": "Predictions received",
#   "total_count": 1400
# }
#
# {
#   "asctime": "2023-02-09 14:13:20",
#   "levelname": "INFO",
#   "lineno": 152,
#   "msg": "Reading file",
#   "file_path": "/Users/ryan.demarigny/PycharmProjects/qa-frame-notebooks/notebooks/input/seldon-onnx-combined_1676003196/seldon-onnx-combined_3.json"
# }
#
# {
#   "asctime": "2023-02-09 14:13:24",
#   "levelname": "INFO",
#   "lineno": 23,
#   "msg": "Predictions received",
#   "total_count": 1450
# }
#
# {
#   "asctime": "2023-02-09 14:13:24",
#   "levelname": "INFO",
#   "lineno": 114,
#   "msg": "Writing file",
#   "file_name": "seldon-meta-combiner-predictor_7.json"
# }
#
# {
#   "asctime": "2023-02-09 14:13:28",
#   "levelname": "INFO",
#   "lineno": 23,
#   "msg": "Predictions received",
#   "total_count": 1500
# }
#
# {
#   "asctime": "2023-02-09 14:13:32",
#   "levelname": "INFO",
#   "lineno": 23,
#   "msg": "Predictions received",
#   "total_count": 1550
# }
#
# {
#   "asctime": "2023-02-09 14:13:36",
#   "levelname": "INFO",
#   "lineno": 23,
#   "msg": "Predictions received",
#   "total_count": 1600
# }
#
# {
#   "asctime": "2023-02-09 14:13:36",
#   "levelname": "INFO",
#   "lineno": 152,
#   "msg": "Reading file",
#   "file_path": "/Users/ryan.demarigny/PycharmProjects/qa-frame-notebooks/notebooks/input/seldon-onnx-combined_1676003196/seldon-onnx-combined_2.json"
# }
#
# {
#   "asctime": "2023-02-09 14:13:41",
#   "levelname": "INFO",
#   "lineno": 23,
#   "msg": "Predictions received",
#   "total_count": 1650
# }
#
# {
#   "asctime": "2023-02-09 14:13:41",
#   "levelname": "INFO",
#   "lineno": 114,
#   "msg": "Writing file",
#   "file_name": "seldon-meta-combiner-predictor_8.json"
# }
#
# {
#   "asctime": "2023-02-09 14:13:45",
#   "levelname": "INFO",
#   "lineno": 23,
#   "msg": "Predictions received",
#   "total_count": 1700
# }
#
# {
#   "asctime": "2023-02-09 14:13:49",
#   "levelname": "INFO",
#   "lineno": 23,
#   "msg": "Predictions received",
#   "total_count": 1750
# }
#
# {
#   "asctime": "2023-02-09 14:13:53",
#   "levelname": "INFO",
#   "lineno": 23,
#   "msg": "Predictions received",
#   "total_count": 1800
# }
#
# {
#   "asctime": "2023-02-09 14:13:53",
#   "levelname": "INFO",
#   "lineno": 152,
#   "msg": "Reading file",
#   "file_path": "/Users/ryan.demarigny/PycharmProjects/qa-frame-notebooks/notebooks/input/seldon-onnx-combined_1676003196/seldon-onnx-combined_15.json"
# }
#
# {
#   "asctime": "2023-02-09 14:13:57",
#   "levelname": "INFO",
#   "lineno": 23,
#   "msg": "Predictions received",
#   "total_count": 1850
# }
#
# {
#   "asctime": "2023-02-09 14:13:57",
#   "levelname": "INFO",
#   "lineno": 114,
#   "msg": "Writing file",
#   "file_name": "seldon-meta-combiner-predictor_9.json"
# }
#
# {
#   "asctime": "2023-02-09 14:14:01",
#   "levelname": "INFO",
#   "lineno": 23,
#   "msg": "Predictions received",
#   "total_count": 1900
# }
#
# {
#   "asctime": "2023-02-09 14:14:05",
#   "levelname": "INFO",
#   "lineno": 23,
#   "msg": "Predictions received",
#   "total_count": 1950
# }
#
# {
#   "asctime": "2023-02-09 14:14:09",
#   "levelname": "INFO",
#   "lineno": 23,
#   "msg": "Predictions received",
#   "total_count": 2000
# }
#
# {
#   "asctime": "2023-02-09 14:14:09",
#   "levelname": "INFO",
#   "lineno": 152,
#   "msg": "Reading file",
#   "file_path": "/Users/ryan.demarigny/PycharmProjects/qa-frame-notebooks/notebooks/input/seldon-onnx-combined_1676003196/seldon-onnx-combined_12.json"
# }
#
# {
#   "asctime": "2023-02-09 14:14:14",
#   "levelname": "INFO",
#   "lineno": 23,
#   "msg": "Predictions received",
#   "total_count": 2050
# }
#
# {
#   "asctime": "2023-02-09 14:14:14",
#   "levelname": "INFO",
#   "lineno": 114,
#   "msg": "Writing file",
#   "file_name": "seldon-meta-combiner-predictor_10.json"
# }
#
# {
#   "asctime": "2023-02-09 14:14:17",
#   "levelname": "INFO",
#   "lineno": 23,
#   "msg": "Predictions received",
#   "total_count": 2100
# }
#
# {
#   "asctime": "2023-02-09 14:14:22",
#   "levelname": "INFO",
#   "lineno": 23,
#   "msg": "Predictions received",
#   "total_count": 2150
# }
#
# {
#   "asctime": "2023-02-09 14:14:25",
#   "levelname": "INFO",
#   "lineno": 23,
#   "msg": "Predictions received",
#   "total_count": 2200
# }
#
# {
#   "asctime": "2023-02-09 14:14:26",
#   "levelname": "INFO",
#   "lineno": 152,
#   "msg": "Reading file",
#   "file_path": "/Users/ryan.demarigny/PycharmProjects/qa-frame-notebooks/notebooks/input/seldon-onnx-combined_1676003196/seldon-onnx-combined_5.json"
# }
#
# {
#   "asctime": "2023-02-09 14:14:30",
#   "levelname": "INFO",
#   "lineno": 23,
#   "msg": "Predictions received",
#   "total_count": 2250
# }
#
# {
#   "asctime": "2023-02-09 14:14:30",
#   "levelname": "INFO",
#   "lineno": 114,
#   "msg": "Writing file",
#   "file_name": "seldon-meta-combiner-predictor_11.json"
# }
#
# {
#   "asctime": "2023-02-09 14:14:34",
#   "levelname": "INFO",
#   "lineno": 23,
#   "msg": "Predictions received",
#   "total_count": 2300
# }
#
# {
#   "asctime": "2023-02-09 14:14:39",
#   "levelname": "INFO",
#   "lineno": 23,
#   "msg": "Predictions received",
#   "total_count": 2350
# }
#
# {
#   "asctime": "2023-02-09 14:14:43",
#   "levelname": "INFO",
#   "lineno": 23,
#   "msg": "Predictions received",
#   "total_count": 2400
# }
#
# {
#   "asctime": "2023-02-09 14:14:43",
#   "levelname": "INFO",
#   "lineno": 152,
#   "msg": "Reading file",
#   "file_path": "/Users/ryan.demarigny/PycharmProjects/qa-frame-notebooks/notebooks/input/seldon-onnx-combined_1676003196/seldon-onnx-combined_9.json"
# }
#
# {
#   "asctime": "2023-02-09 14:14:47",
#   "levelname": "INFO",
#   "lineno": 23,
#   "msg": "Predictions received",
#   "total_count": 2450
# }
#
# {
#   "asctime": "2023-02-09 14:14:47",
#   "levelname": "INFO",
#   "lineno": 114,
#   "msg": "Writing file",
#   "file_name": "seldon-meta-combiner-predictor_12.json"
# }
#
# {
#   "asctime": "2023-02-09 14:14:51",
#   "levelname": "INFO",
#   "lineno": 23,
#   "msg": "Predictions received",
#   "total_count": 2500
# }
#
# {
#   "asctime": "2023-02-09 14:14:56",
#   "levelname": "INFO",
#   "lineno": 23,
#   "msg": "Predictions received",
#   "total_count": 2550
# }
#
# {
#   "asctime": "2023-02-09 14:14:59",
#   "levelname": "INFO",
#   "lineno": 23,
#   "msg": "Predictions received",
#   "total_count": 2600
# }
#
# {
#   "asctime": "2023-02-09 14:15:00",
#   "levelname": "INFO",
#   "lineno": 152,
#   "msg": "Reading file",
#   "file_path": "/Users/ryan.demarigny/PycharmProjects/qa-frame-notebooks/notebooks/input/seldon-onnx-combined_1676003196/seldon-onnx-combined_8.json"
# }
#
# {
#   "asctime": "2023-02-09 14:15:04",
#   "levelname": "INFO",
#   "lineno": 23,
#   "msg": "Predictions received",
#   "total_count": 2650
# }
#
# {
#   "asctime": "2023-02-09 14:15:04",
#   "levelname": "INFO",
#   "lineno": 114,
#   "msg": "Writing file",
#   "file_name": "seldon-meta-combiner-predictor_13.json"
# }
#
# {
#   "asctime": "2023-02-09 14:15:08",
#   "levelname": "INFO",
#   "lineno": 23,
#   "msg": "Predictions received",
#   "total_count": 2700
# }
#
# {
#   "asctime": "2023-02-09 14:15:12",
#   "levelname": "INFO",
#   "lineno": 23,
#   "msg": "Predictions received",
#   "total_count": 2750
# }
#
# {
#   "asctime": "2023-02-09 14:15:16",
#   "levelname": "INFO",
#   "lineno": 23,
#   "msg": "Predictions received",
#   "total_count": 2800
# }
#
# {
#   "asctime": "2023-02-09 14:15:16",
#   "levelname": "INFO",
#   "lineno": 152,
#   "msg": "Reading file",
#   "file_path": "/Users/ryan.demarigny/PycharmProjects/qa-frame-notebooks/notebooks/input/seldon-onnx-combined_1676003196/seldon-onnx-combined_4.json"
# }
#
# {
#   "asctime": "2023-02-09 14:15:20",
#   "levelname": "INFO",
#   "lineno": 23,
#   "msg": "Predictions received",
#   "total_count": 2850
# }
#
# {
#   "asctime": "2023-02-09 14:15:20",
#   "levelname": "INFO",
#   "lineno": 114,
#   "msg": "Writing file",
#   "file_name": "seldon-meta-combiner-predictor_14.json"
# }
#
# {
#   "asctime": "2023-02-09 14:15:24",
#   "levelname": "INFO",
#   "lineno": 23,
#   "msg": "Predictions received",
#   "total_count": 2900
# }
#
# {
#   "asctime": "2023-02-09 14:15:28",
#   "levelname": "INFO",
#   "lineno": 23,
#   "msg": "Predictions received",
#   "total_count": 2950
# }
#
# {
#   "asctime": "2023-02-09 14:15:32",
#   "levelname": "INFO",
#   "lineno": 23,
#   "msg": "Predictions received",
#   "total_count": 3000
# }
#
# {
#   "asctime": "2023-02-09 14:15:32",
#   "levelname": "INFO",
#   "lineno": 152,
#   "msg": "Reading file",
#   "file_path": "/Users/ryan.demarigny/PycharmProjects/qa-frame-notebooks/notebooks/input/seldon-onnx-combined_1676003196/seldon-onnx-combined_13.json"
# }
#
# {
#   "asctime": "2023-02-09 14:15:36",
#   "levelname": "INFO",
#   "lineno": 23,
#   "msg": "Predictions received",
#   "total_count": 3050
# }
#
# {
#   "asctime": "2023-02-09 14:15:36",
#   "levelname": "INFO",
#   "lineno": 114,
#   "msg": "Writing file",
#   "file_name": "seldon-meta-combiner-predictor_15.json"
# }
#
# {
#   "asctime": "2023-02-09 14:15:41",
#   "levelname": "INFO",
#   "lineno": 23,
#   "msg": "Predictions received",
#   "total_count": 3100
# }
#
# {
#   "asctime": "2023-02-09 14:15:44",
#   "levelname": "INFO",
#   "lineno": 23,
#   "msg": "Predictions received",
#   "total_count": 3150
# }
#
# {
#   "asctime": "2023-02-09 14:15:49",
#   "levelname": "INFO",
#   "lineno": 23,
#   "msg": "Predictions received",
#   "total_count": 3200
# }
#
# {
#   "asctime": "2023-02-09 14:15:49",
#   "levelname": "INFO",
#   "lineno": 165,
#   "msg": "Finished reading JSON files",
#   "successfully_read": 3239,
#   "unsuccessfully_read": 0
# }
#
# {
#   "asctime": "2023-02-09 14:15:56",
#   "levelname": "INFO",
#   "lineno": 23,
#   "msg": "Predictions received",
#   "total_count": 3239
# }
#
# {
#   "asctime": "2023-02-09 14:15:56",
#   "levelname": "INFO",
#   "lineno": 114,
#   "msg": "Writing file",
#   "file_name": "seldon-meta-combiner-predictor_16.json"
# }
